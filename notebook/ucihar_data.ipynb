# %%
import torch
import collections
import numpy as np

# %%
x_train = np.load('../benchmark/RAW_DATA/UCIHAR/x_train.npy', allow_pickle=True)
y_train = np.load('../benchmark/RAW_DATA/UCIHAR/y_train.npy', allow_pickle=True)
x_test = np.load('../benchmark/RAW_DATA/UCIHAR/x_test.npy', allow_pickle=True)
y_test = np.load('../benchmark/RAW_DATA/UCIHAR/y_test.npy', allow_pickle=True)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((7352, 2, 384), (7352,), (2947, 2, 384), (2947,))

# %%
x_train[0,:]
# Out:
# array([[-7.07495241e-01,  2.69420690e+00,  3.43982825e+00,
#          2.66682221e+00,  1.78603038e+00,  3.41628707e+00,
#          2.37438658e+00,  2.29558375e+00,  3.05332023e+00,
#          9.47874996e-01,  1.98322449e+00,  3.12732980e+00,
#          2.89443434e+00,  1.69092249e+00,  2.76210903e+00,
#          6.01963107e-01,  1.86515870e+00,  2.85480193e+00,
#          8.43327733e-01,  1.12950174e+00,  2.80023295e+00,
#          1.33680713e+00,  9.09297675e-01,  2.34974811e+00,
#          3.51759869e-01,  1.24490915e+00,  2.12339574e+00,
#          1.79708523e+00,  1.46915186e+00,  1.71179207e+00,
#          1.06350246e+00,  1.63698318e+00,  1.57315808e+00,
#          1.33939233e+00,  1.93142933e+00,  1.31101189e+00,
#          1.56770321e+00,  2.48251760e+00,  1.08337781e+00,
#          7.93475630e-01,  2.02062770e+00,  1.25109462e+00,
#          1.71555164e+00,  1.48453173e+00,  1.16374730e+00,
#          9.51863435e-01,  1.83886378e+00,  9.81242515e-01,
# ...
